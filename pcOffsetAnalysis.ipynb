# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as spec
import pandas as pd
from astropy.io import ascii
import scipy.stats as stats
import requests
import astropy.units as u
from astropy.coordinates import SkyCoord

# %%
cfpTableBerger = pd.read_csv("cfpTable_Berger2020.csv")
cfpTable = pd.read_csv("cfpTable.csv")
cfpTableBerger
# Out:
#      kepoi_name  fpwg_koi_period fpwg_disp_status  fpwg_disp_source  \
# 0     K00889.01             8.88     NOT EXAMINED               NaN
# 1     K00958.01            21.76  POSSIBLE PLANET               1.0
# 2     K00994.01             4.30     NOT EXAMINED               NaN
# 3     K00992.01             9.93     NOT EXAMINED               NaN
# 4     K00992.02             4.58     NOT EXAMINED               NaN
# ...         ...              ...              ...               ...
# 3475  K03663.01           282.53     NOT EXAMINED               NaN
# 3476  K04245.01            24.67     NOT EXAMINED               NaN
# 3477  K03848.01             1.85     NOT EXAMINED               NaN
# 3478  K00487.01             7.66     NOT EXAMINED               NaN
# 3479  K02184.02            95.91     NOT EXAMINED               NaN
#
#       fpwg_disp_eb  fpwg_disp_offst  fpwg_disp_perep  fpwg_disp_other  \
# 0              NaN              NaN              NaN              NaN
# 1              0.0              0.0              0.0              0.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
# ...            ...              ...              ...              ...
# 3475           NaN              NaN              NaN              NaN
# 3476           NaN              NaN              NaN              NaN
# 3477           NaN              NaN              NaN              NaN
# 3478           NaN              NaN              NaN              NaN
# 3479           NaN              NaN              NaN              NaN
#
#       fpwg_flux_ss  fpwg_flux_slflum  ...  gaia_iso_prad_errp  \
# 0              NaN               NaN  ...            0.365917
# 1              0.0               0.0  ...            0.075542
# 2              NaN               NaN  ...            0.191499
# 3              NaN               NaN  ...            0.195062
# 4              NaN               NaN  ...            0.123157
# ...            ...               ...  ...                 ...
# 3475           NaN               NaN  ...            0.153577
# 3476           NaN               NaN  ...            0.501255
# 3477           NaN               NaN  ...            0.072543
# 3478           NaN               NaN  ...            0.081227
# 3479           NaN               NaN  ...            0.051715
#
#       gaia_iso_prad_errm  gaia_iso_sma  gaia_iso_sma_errp  gaia_iso_sma_errm  \
# 0               0.348698      0.081470           0.001836           0.001695
# 1               0.071506      0.137897           0.001955           0.002193
# 2               0.560965      0.050515           0.000565           0.000660
# 3               0.161632      0.094233           0.002471           0.002316
# 4               0.166306      0.056234           0.001475           0.001382
# ...                  ...           ...                ...                ...
# 3475            0.158708      0.832900           0.012548           0.016892
# 3476            0.222365      0.188908           0.002651           0.003459
# 3477            0.057996      0.029440           0.000701           0.000676
# 3478            0.057070      0.072682           0.001094           0.001464
# 3479            0.213485      0.355365           0.004832           0.003470
#
#       gaia_iso_insol  gaia_iso_insol_errp  gaia_iso_insol_errm    ZAMSFlux  \
# 0          99.074031             9.738625             8.906194   58.665716
# 1          12.658820             0.866631             0.823744   10.322821
# 2         237.802908            19.200212            19.702555  202.822729
# 3         259.790179            33.779281            30.309031  119.867729
# 4         729.506534            94.854265            85.109592  336.595832
# ...              ...                  ...                  ...         ...
# 3475        1.260151             0.140590             0.125640    1.017934
# 3476      164.313139            14.875920            14.122871   85.404183
# 3477     1382.881810           120.810942           112.090230  772.088748
# 3478      105.648367             8.761371             8.011597   85.209273
# 3479        1.657154             0.142122             0.126755    1.214702
#
#       Flag
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 3475    HZ
# 3476   NaN
# 3477   NaN
# 3478   NaN
# 3479   NaN
#
# [3480 rows x 383 columns]

# %%
fp = cfpTableBerger[cfpTableBerger.koi_pdisposition == "FALSE POSITIVE"];
pc = cfpTableBerger[cfpTableBerger.koi_pdisposition == "CANDIDATE"];
certifiedFP = cfpTableBerger[cfpTableBerger.fpwg_disp_status == "CERTIFIED FP"];
# pick out the PCs that have not been looked at by the FPWG
pcNotcertifiedFP = pc[cfpTableBerger.fpwg_disp_status == "NOT EXAMINED"];
# Out:
# /opt/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
pcNotcertifiedFPLowAPP = pcNotcertifiedFP[~np.isnan(pcNotcertifiedFP.pp_host_rel_prob)]
pcNotcertifiedFPLowAPP = pcNotcertifiedFPLowAPP[pcNotcertifiedFP.pp_host_prob_score > 0.3]
pcNotcertifiedFPLowAPP = pcNotcertifiedFPLowAPP[pcNotcertifiedFP.pp_host_rel_prob < 0.3]
pcNotcertifiedFPLowAPP
# Out:
# /opt/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /opt/anaconda3/envs/py3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      kepoi_name  fpwg_koi_period fpwg_disp_status  fpwg_disp_source  \
# 3     K00992.01             9.93     NOT EXAMINED               NaN
# 12    K07624.01           330.03     NOT EXAMINED               NaN
# 13    K04212.01             5.79     NOT EXAMINED               NaN
# 110   K02186.01            14.98     NOT EXAMINED               NaN
# 216   K04992.01            12.57     NOT EXAMINED               NaN
# 226   K03398.03             4.33     NOT EXAMINED               NaN
# 278   K04526.01            30.54     NOT EXAMINED               NaN
# 317   K00393.01            21.42     NOT EXAMINED               NaN
# 378   K01934.01            28.78     NOT EXAMINED               NaN
# 395   K04810.01           115.24     NOT EXAMINED               NaN
# 401   K01619.01            20.67     NOT EXAMINED               NaN
# 497   K02243.01             5.19     NOT EXAMINED               NaN
# 535   K02617.01             8.63     NOT EXAMINED               NaN
# 548   K00501.01            24.80     NOT EXAMINED               NaN
# 789   K04913.01             6.79     NOT EXAMINED               NaN
# 840   K07749.01           133.63     NOT EXAMINED               NaN
# 1004  K03040.01             4.81     NOT EXAMINED               NaN
# 1065  K02840.02             7.45     NOT EXAMINED               NaN
# 1275  K03689.01             5.24     NOT EXAMINED               NaN
# 1574  K07850.01            66.12     NOT EXAMINED               NaN
# 1635  K00316.03             7.31     NOT EXAMINED               NaN
# 1842  K07884.01             0.71     NOT EXAMINED               NaN
# 2012  K05566.01             0.99     NOT EXAMINED               NaN
# 2112  K01874.02             7.42     NOT EXAMINED               NaN
# 2387  K00710.03             3.89     NOT EXAMINED               NaN
# 2626  K00426.01            16.30     NOT EXAMINED               NaN
# 2863  K00598.02            34.10     NOT EXAMINED               NaN
# 2923  K02736.01             9.34     NOT EXAMINED               NaN
# 3050  K02442.01            25.19     NOT EXAMINED               NaN
# 3209  K04586.01            75.21     NOT EXAMINED               NaN
# 3287  K03116.01            23.91     NOT EXAMINED               NaN
# 3368  K03261.01            12.27     NOT EXAMINED               NaN
# 3428  K08078.01             0.81     NOT EXAMINED               NaN
#
#       fpwg_disp_eb  fpwg_disp_offst  fpwg_disp_perep  fpwg_disp_other  \
# 3              NaN              NaN              NaN              NaN
# 12             NaN              NaN              NaN              NaN
# 13             NaN              NaN              NaN              NaN
# 110            NaN              NaN              NaN              NaN
# 216            NaN              NaN              NaN              NaN
# 226            NaN              NaN              NaN              NaN
# 278            NaN              NaN              NaN              NaN
# 317            NaN              NaN              NaN              NaN
# 378            NaN              NaN              NaN              NaN
# 395            NaN              NaN              NaN              NaN
# 401            NaN              NaN              NaN              NaN
# 497            NaN              NaN              NaN              NaN
# 535            NaN              NaN              NaN              NaN
# 548            NaN              NaN              NaN              NaN
# 789            NaN              NaN              NaN              NaN
# 840            NaN              NaN              NaN              NaN
# 1004           NaN              NaN              NaN              NaN
# 1065           NaN              NaN              NaN              NaN
# 1275           NaN              NaN              NaN              NaN
# 1574           NaN              NaN              NaN              NaN
# 1635           NaN              NaN              NaN              NaN
# 1842           NaN              NaN              NaN              NaN
# 2012           NaN              NaN              NaN              NaN
# 2112           NaN              NaN              NaN              NaN
# 2387           NaN              NaN              NaN              NaN
# 2626           NaN              NaN              NaN              NaN
# 2863           NaN              NaN              NaN              NaN
# 2923           NaN              NaN              NaN              NaN
# 3050           NaN              NaN              NaN              NaN
# 3209           NaN              NaN              NaN              NaN
# 3287           NaN              NaN              NaN              NaN
# 3368           NaN              NaN              NaN              NaN
# 3428           NaN              NaN              NaN              NaN
#
#       fpwg_flux_ss  fpwg_flux_slflum  ...  gaia_iso_prad_errp  \
# 3              NaN               NaN  ...            0.195062
# 12             NaN               NaN  ...            0.315481
# 13             NaN               NaN  ...            0.045383
# 110            NaN               NaN  ...            0.226312
# 216            NaN               NaN  ...            0.079451
# 226            NaN               NaN  ...            0.110978
# 278            NaN               NaN  ...            0.163825
# 317            NaN               NaN  ...            0.097277
# 378            NaN               NaN  ...            0.107161
# 395            NaN               NaN  ...            0.114322
# 401            NaN               NaN  ...            0.046816
# 497            NaN               NaN  ...            0.110815
# 535            NaN               NaN  ...            0.052509
# 548            NaN               NaN  ...            0.147948
# 789            NaN               NaN  ...            0.107987
# 840            NaN               NaN  ...            0.087385
# 1004           NaN               NaN  ...            0.108409
# 1065           NaN               NaN  ...            0.053477
# 1275           NaN               NaN  ...            0.338605
# 1574           NaN               NaN  ...            0.343085
# 1635           NaN               NaN  ...            0.037978
# 1842           NaN               NaN  ...            0.219802
# 2012           NaN               NaN  ...            0.121283
# 2112           NaN               NaN  ...            0.045289
# 2387           NaN               NaN  ...            0.066103
# 2626           NaN               NaN  ...            0.322473
# 2863           NaN               NaN  ...            0.064350
# 2923           NaN               NaN  ...            0.070702
# 3050           NaN               NaN  ...            0.412072
# 3209           NaN               NaN  ...            0.172649
# 3287           NaN               NaN  ...            0.213288
# 3368           NaN               NaN  ...            0.077555
# 3428           NaN               NaN  ...         2811.854737
#
#       gaia_iso_prad_errm  gaia_iso_sma  gaia_iso_sma_errp  gaia_iso_sma_errm  \
# 3               0.161632      0.094233           0.002471           0.002316
# 12              0.405236      1.128970           0.015410           0.016422
# 13              0.264666      0.067724           0.000846           0.001050
# 110             0.840419      0.110650           0.002127           0.001658
# 216             0.169851      0.103741           0.001691           0.002132
# 226             0.091178      0.057940           0.000882           0.000812
# 278             0.178787      0.193813           0.004645           0.004582
# 317             0.074456      0.164043           0.002178           0.001875
# 378             0.061498      0.162063           0.002292           0.002049
# 395             0.799684      0.445026           0.005752           0.006305
# 401             0.039334      0.131968           0.002200           0.001619
# 497             0.080947      0.064214           0.000768           0.000779
# 535             0.135265      0.076103           0.001295           0.001573
# 548             0.134579      0.180967           0.006066           0.006659
# 789             0.101044      0.077289           0.000808           0.000921
# 840             0.162251      0.485026           0.007249           0.009066
# 1004            0.101109      0.054055           0.001135           0.001265
# 1065            0.115297      0.077515           0.001997           0.002094
# 1275            0.340224      0.061254           0.001319           0.001497
# 1574            0.337757      0.313480           0.008220           0.007699
# 1635            0.234939      0.075756           0.000917           0.001302
# 1842            0.211852      0.016311           0.000372           0.000448
# 2012            0.116590      0.020908           0.000258           0.000301
# 2112            0.092550      0.065141           0.000955           0.000757
# 2387            0.060598      0.052512           0.000882           0.001532
# 2626            0.229780      0.116934           0.002308           0.002437
# 2863            0.086627      0.193514           0.003022           0.004235
# 2923            0.493146      0.075965           0.001032           0.001037
# 3050            0.170369      0.157866           0.002978           0.002888
# 3209            0.123335      0.359001           0.007405           0.007995
# 3287            0.280511      0.172228           0.003620           0.004533
# 3368            0.070648      0.102515           0.001344           0.001817
# 3428           18.387767      0.016472           0.000834           0.000640
#
#       gaia_iso_insol  gaia_iso_insol_errp  gaia_iso_insol_errm     ZAMSFlux  \
# 3         259.790179            33.779281            30.309031   119.867729
# 12         10.508727             1.082820             1.024214     7.444600
# 13        502.730518            39.342938            41.897644   381.135675
# 110        32.018883             3.521132             3.122714    20.983883
# 216        74.423361             8.282145             7.863990    59.947067
# 226      1204.625437            95.354162           113.142931   812.659872
# 278        43.263274             6.724243             5.973693    27.007001
# 317       138.554383            12.234074            10.325373   103.605107
# 378         7.688891             0.607343             0.534053     6.023728
# 395         3.226014             0.306625             0.300795     2.784485
# 401        14.566394             1.051593             0.926867    10.415048
# 497       791.685483            84.425916            76.240870   608.469575
# 535        63.544545             7.049409             6.485504    53.108563
# 548       106.258946            47.891215            18.154011    60.232617
# 789       599.816430            48.211767            44.174437   471.436849
# 840         1.733240             0.122343             0.122315     1.377418
# 1004      243.917207            30.109843            27.648322   171.439818
# 1065      415.136270            37.260549            37.290528   200.157250
# 1275      547.923411            49.055484            45.628769   318.040036
# 1574       11.971819             2.127183             1.898632     5.589046
# 1635      184.581512            12.601932            12.015235   141.920693
# 1842     9000.256209          1525.746524          1301.548728  5167.157793
# 2012     5505.992178           381.001799           376.546750  4158.493686
# 2112       49.691472             4.566544             4.059938    38.323011
# 2387     1575.518167           129.648152           141.736108   824.630457
# 2626       40.747303             3.787401             3.377495    28.793727
# 2863       11.589971             0.954136             0.918727     9.427527
# 2923       27.749395             2.692833             2.290082    23.590018
# 3050       16.399882             1.782460             1.630869    11.771403
# 3209       12.999720             1.145491             1.099958     7.686274
# 3287       97.011152            15.966972            14.687210    55.322595
# 3368       80.625415             6.298537             6.336347    66.979050
# 3428    16483.189611          2110.137890          1720.986456  2650.950180
#
#          Flag
# 3         NaN
# 12        NaN
# 13        NaN
# 110       NaN
# 216        AO
# 226       NaN
# 278        AO
# 317       NaN
# 378       NaN
# 395        AO
# 401        AO
# 497   YoungAO
# 535       NaN
# 548       NaN
# 789       NaN
# 840       NaN
# 1004      NaN
# 1065      NaN
# 1275      NaN
# 1574      NaN
# 1635      NaN
# 1842      NaN
# 2012      Old
# 2112      NaN
# 2387      NaN
# 2626      NaN
# 2863       AO
# 2923      NaN
# 3050      NaN
# 3209      NaN
# 3287      NaN
# 3368      NaN
# 3428      NaN
#
# [33 rows x 383 columns]

# %%
len(pcNotcertifiedFPLowAPP)
# Out:
# 33

# %%
pcNotcertifiedFPLowAPP.kepoi_name
# Out:
# 3       K00992.01
# 12      K07624.01
# 13      K04212.01
# 110     K02186.01
# 216     K04992.01
# 226     K03398.03
# 278     K04526.01
# 317     K00393.01
# 378     K01934.01
# 395     K04810.01
# 401     K01619.01
# 497     K02243.01
# 535     K02617.01
# 548     K00501.01
# 789     K04913.01
# 840     K07749.01
# 1004    K03040.01
# 1065    K02840.02
# 1275    K03689.01
# 1574    K07850.01
# 1635    K00316.03
# 1842    K07884.01
# 2012    K05566.01
# 2112    K01874.02
# 2387    K00710.03
# 2626    K00426.01
# 2863    K00598.02
# 2923    K02736.01
# 3050    K02442.01
# 3209    K04586.01
# 3287    K03116.01
# 3368    K03261.01
# 3428    K08078.01
# Name: kepoi_name, dtype: object
